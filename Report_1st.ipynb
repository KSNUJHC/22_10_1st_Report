# %% [markdown]
# <a href="https://colab.research.google.com/github/KSNUJHC/22_10_1st_Report/blob/main/Report_1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("환영합니다.")
print("파이썬의 세계에 오신 것을 환영합니다.")
print("파이썬은 강력합니다.")
# Out:
# 환영합니다.
# 파이썬의 세계에 오신 것을 환영합니다.
# 파이썬은 강력합니다.

# %%
print("반갑습니다. 파이썬!")
print(2*3/10)
print("Hello","world","!!!")
# Out:
# 반갑습니다. 파이썬!
# 0.6
# Hello world !!!

# %%
hours=1
day=24*hours
week=7*day
time=week
print(time)
# Out:
# 168

# %%
import turtle
turtle.shape('turtle')
turtle.forward(100)
turtle.left(90)
turtle.forward(100)
turtle.right(90)
turtle.forward(100)
turtle.right(90)
turtle.forward(100)
turtle.left(90)
turtle.forward(100)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-6-24ab3720dc40> in <module>
#       1 import turtle
# ----> 2 turtle.shape('turtle')
#       3 turtle.forward(100)
#       4 turtle.left(90)
#       5 turtle.forward(100)
#
# /usr/lib/python3.7/turtle.py in shape(name)
#
# /usr/lib/python3.7/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3810                  visible=_CFG["visible"]):
#    3811         if Turtle._screen is None:
# -> 3812             Turtle._screen = Screen()
#    3813         RawTurtle.__init__(self, Turtle._screen,
#    3814                            shape=shape,
#
# /usr/lib/python3.7/turtle.py in Screen()
#    3660     else return the existing one."""
#    3661     if Turtle._screen is None:
# -> 3662         Turtle._screen = _Screen()
#    3663     return Turtle._screen
#    3664
#
# ...
